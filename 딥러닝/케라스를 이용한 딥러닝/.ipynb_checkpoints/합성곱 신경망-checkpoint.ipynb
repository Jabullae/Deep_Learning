# %% [markdown]
# # 합성곱 신경망

# %% [markdown]
# ## 간단한 커브넷 만들기

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape = (28, 28, 1))
x = layers.Conv2D(filters = 32, kernel_size = 3, activation = 'relu')(inputs)
x = layers.MaxPooling2D(pool_size = 2)(x)
x = layers.Conv2D(filters = 64, kernel_size = 3, activation = 'relu')(x)
x = layers.MaxPooling2D(pool_size = 2)(x)
x = layers.Conv2D(filters = 128, kernel_size = 3, activation = 'relu')(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation = 'softmax')(x)
model = keras.Model(inputs = inputs, outputs = outputs)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_1 (Dense)             (None, 10)                11530
#
# =================================================================
# Total params: 104,202
# Trainable params: 104,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255
model.compile(optimizer='rmsprop',
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])
model.fit(train_images, train_labels, epochs = 5, batch_size = 64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 20s 20ms/step - loss: 0.1627 - accuracy: 0.9491
# Epoch 2/5
# 938/938 [==============================] - 23s 24ms/step - loss: 0.0454 - accuracy: 0.9858
# Epoch 3/5
# 938/938 [==============================] - 21s 23ms/step - loss: 0.0316 - accuracy: 0.9904
# Epoch 4/5
# 938/938 [==============================] - 21s 22ms/step - loss: 0.0234 - accuracy: 0.9925
# Epoch 5/5
# 938/938 [==============================] - 21s 22ms/step - loss: 0.0183 - accuracy: 0.9945

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'테스트 정확도 : {test_acc:.3f}')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0268 - accuracy: 0.9904
# 테스트 정확도 : 0.990

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (20, 5))
for i in range(20):
    plt.subplot(2, 10, i+1)
    digit = train_images[i]
    plt.imshow(digit, cmap = plt.cm.binary)
plt.show()
